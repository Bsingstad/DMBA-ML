# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.sparse import csr_matrix
from mpl_toolkits.axes_grid1 import make_axes_locatable
from sklearn.cluster import KMeans
from sklearn.metrics import mean_squared_error
import itertools
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.pipeline import make_pipeline
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
# Import the ratings dataset
ratings = pd.read_csv('ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
new_ratings = ratings.iloc[np.isin(ratings["movieId"],ratings["movieId"].unique()[:5] )]

# %%
user_movie = pd.crosstab(new_ratings.userId,new_ratings.movieId, values=new_ratings.rating, aggfunc="mean")

# %%
user_movie_train, user_movie_test = train_test_split(user_movie, test_size=0.3)

# %%
from sklearn.cluster import KMeans
elbow = [] 
for i in range(1, 15):
    kmeans = make_pipeline(KNNImputer(n_neighbors=3),KMeans(n_clusters = i, init = 'k-means++', random_state = 42))
    #kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(user_movie_train) 
    elbow.append(kmeans.named_steps['kmeans'].inertia_)
    print("Kmeans med {} klynger".format(i))
# Out:
# C:\Users\Bjorn\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Kmeans med 1 klynger
# C:\Users\Bjorn\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Kmeans med 2 klynger
# C:\Users\Bjorn\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Kmeans med 3 klynger
# C:\Users\Bjorn\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Kmeans med 4 klynger
# C:\Users\Bjorn\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Kmeans med 5 klynger
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 6
#       4 kmeans = make_pipeline(KNNImputer(n_neighbors=3),KMeans(n_clusters = i, init = 'k-means++', random_state = 42))
#       5 #kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
# ----> 6 kmeans.fit(user_movie_train)
#       7 elbow.append(kmeans.named_steps['kmeans'].inertia_)
#       8 print("Kmeans med {} klynger".format(i))
#
# File ~\anaconda3\lib\site-packages\sklearn\pipeline.py:402, in Pipeline.fit(self, X, y, **fit_params)
#     376 """Fit the model.
#     377
#     378 Fit all the transformers one after the other and transform the
#    (...)
#     399     Pipeline with fitted steps.
#     400 """
#     401 fit_params_steps = self._check_fit_params(**fit_params)
# --> 402 Xt = self._fit(X, y, **fit_params_steps)
#     403 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     404     if self._final_estimator != "passthrough":
#
# File ~\anaconda3\lib\site-packages\sklearn\pipeline.py:360, in Pipeline._fit(self, X, y, **fit_params_steps)
#     358     cloned_transformer = clone(transformer)
#     359 # Fit or load from cache the current transformer
# --> 360 X, fitted_transformer = fit_transform_one_cached(
#     361     cloned_transformer,
#     362     X,
#     363     y,
#     364     None,
#     365     message_clsname="Pipeline",
#     366     message=self._log_message(step_idx),
#     367     **fit_params_steps[name],
#     368 )
#     369 # Replace the transformer of the step with the fitted
#     370 # transformer. This is necessary when loading the transformer
#     371 # from the cache.
#     372 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~\anaconda3\lib\site-packages\joblib\memory.py:349, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     348 def __call__(self, *args, **kwargs):
# --> 349     return self.func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sklearn\pipeline.py:894, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     892 with _print_elapsed_time(message_clsname, message):
#     893     if hasattr(transformer, "fit_transform"):
# --> 894         res = transformer.fit_transform(X, y, **fit_params)
#     895     else:
#     896         res = transformer.fit(X, y, **fit_params).transform(X)
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:848, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     844 # non-optimized default implementation; override when a better
#     845 # method is possible for a given clustering algorithm
#     846 if y is None:
#     847     # fit method of arity 1 (unsupervised transformation)
# --> 848     return self.fit(X, **fit_params).transform(X)
#     849 else:
#     850     # fit method of arity 2 (supervised transformation)
#     851     return self.fit(X, y, **fit_params).transform(X)
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# File ~\anaconda3\lib\site-packages\sklearn\impute\_knn.py:357, in KNNImputer.transform(self, X)
#     348 # process in fixed-memory chunks
#     349 gen = pairwise_distances_chunked(
#     350     X[row_missing_idx, :],
#     351     self._fit_X,
#    (...)
#     355     reduce_func=process_chunk,
#     356 )
# --> 357 for chunk in gen:
#     358     # process_chunk modifies X in place. No return value.
#     359     pass
#     361 if self.keep_empty_features:
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1867, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1865 else:
#    1866     X_chunk = X[sl]
# -> 1867 D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    1868 if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    1869     metric, None
#    1870 ) is euclidean_distances:
#    1871     # zeroing diagonal, taking care of aliases of "euclidean",
#    1872     # i.e. "l2"
#    1873     D_chunk.flat[sl.start :: _num_samples(X) + 1] = 0
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:2039, in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    2036         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    2037     func = partial(distance.cdist, metric=metric, **kwds)
# -> 2039 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1579, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1576 X, Y, dtype = _return_float_dtype(X, Y)
#    1578 if effective_n_jobs(n_jobs) == 1:
# -> 1579     return func(X, Y, **kwds)
#    1581 # enforce a threading backend to prevent data communication overhead
#    1582 fd = delayed(_dist_wrapper)
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:474, in nan_euclidean_distances(X, Y, squared, missing_values, copy)
#     471 X[missing_X] = 0
#     472 Y[missing_Y] = 0
# --> 474 distances = euclidean_distances(X, Y, squared=True)
#     476 # Adjust distances for missing values
#     477 XX = X * X
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:328, in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     322     if Y_norm_squared.shape != (1, Y.shape[0]):
#     323         raise ValueError(
#     324             f"Incompatible dimensions for Y of shape {Y.shape} and "
#     325             f"Y_norm_squared of shape {original_shape}."
#     326         )
# --> 328 return _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:369, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     366     distances = _euclidean_distances_upcast(X, XX, Y, YY)
#     367 else:
#     368     # if dtype is already float64, no need to chunk and upcast
# --> 369     distances = -2 * safe_sparse_dot(X, Y.T, dense_output=True)
#     370     distances += XX
#     371     distances += YY
#
# KeyboardInterrupt:

# %%
plt.figure()
plt.plot(elbow)
plt.xticks(np.arange(0,14),np.arange(1,15))
plt.show()

# %%
kmeans =  make_pipeline(KNNImputer(n_neighbors=3),KMeans(n_clusters = 12, init = 'k-means++', random_state = 42))
kmeans.fit(user_movie_train)
# Out:
# C:\Users\Bjorn\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Pipeline(steps=[('knnimputer', KNNImputer(n_neighbors=3)),
#                 ('kmeans', KMeans(n_clusters=12, random_state=42))])

# %%
y_user_movie_hat = kmeans.predict(user_movie_test)

# %%
from sklearn.manifold import TSNE
tsne = TSNE(random_state=42) # use fit_transform instead of fit, as TSNE has no transform method 
movie_tsne = tsne.fit_transform(kmeans["knnimputer"].transform(user_movie_train))

# %%
for i in sorted(np.unique(y_user_movie_hat)):
    temp_scatter = movie_tsne[np.where(y_user_movie_hat==i)]
    plt.scatter(x=temp_scatter[:,0],y=temp_scatter[:,1], color="C{}".format(i))
plt.legend()
plt.show()

# %%
from sklearn.decomposition import PCA
pca =  PCA(n_components=2)

movie_pca = pca.fit_transform(kmeans["knnimputer"].transform(user_movie_train))

# %%
for i in sorted(np.unique(y_user_movie_hat)):
    temp_scatter = movie_pca[np.where(y_user_movie_hat==i)]
    plt.scatter(x=temp_scatter[:,0],y=temp_scatter[:,1], color="C{}".format(i))
plt.show()

# %% [markdown]
# ### Designe anbefalingssystem

# %%
test_not_nan = user_movie_test.loc[user_movie_test.isnull().any(axis=1) == False]

# %%
class abonnent():
    def __init__(self, fasit):
        self.fasit = fasit
        self.idx1 = None
        self.filmer_sett = np.ones((1,5))*np.nan
    
    def start(self):
        self.idx1 = np.random.choice(len(self.fasit[0]))
        self.filmer_sett[0][self.idx1] = self.fasit[0][self.idx1]
        return self.filmer_sett
    
    def ny_film(self, anbefaling):
        if np.isin(anbefaling, np.where(np.isnan(self.filmer_sett))[1]) == True:
            self.filmer_sett[0][anbefaling] = self.fasit[0][anbefaling]
            print("Abonnentens rating = ", self.fasit[0][anbefaling])
            return self.filmer_sett
        else:
            print("denne filmen har jeg sett!")
            return self.filmer_sett

# %%
class anbefalingssystem():
    def __init__(self, modell):
        self.model = modell
        self.pred = []
        #self.filmer_sett = np.ones((1,5))
    
    def anbefaling(self, rating):
        pred_class = self.model.predict(rating)
        self.pred.append(pred_class[0])
        cluster_ratings = self.model["kmeans"].cluster_centers_[pred_class]
        sett_idx = np.where(~np.isnan(rating))[1]
        cluster_ratings[0][sett_idx] = 0
        new_movie = np.argmax(cluster_ratings)
        print("Anbefaler film nr.", new_movie)
        print("Predikert rating = ", cluster_ratings.max())
        return new_movie

# %%
for i in range(len(test_not_nan)):
    abo = abonnent(np.asarray([test_not_nan.iloc[i]]))
    anbef = anbefalingssystem(kmeans)
    film_array = abo.start()
    for i in range(4):
        ny_film = anbef.anbefaling(film_array)
        film = abo.ny_film(ny_film)
    print(anbef.pred)
    print("----------------")
# Out:
# Anbefaler film nr. 2
# Predikert rating =  4.557173895550013
# Abonnentens rating =  5.0
# Anbefaler film nr. 3
# Predikert rating =  4.912352551358515
# Abonnentens rating =  5.0
# Anbefaler film nr. 4
# Predikert rating =  3.983856858846919
# Abonnentens rating =  3.5
# Anbefaler film nr. 1
# Predikert rating =  3.389224652087476
# Abonnentens rating =  4.5
# [0, 5, 5, 5]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.16910519020484
# Abonnentens rating =  4.5
# Anbefaler film nr. 3
# Predikert rating =  4.422424702606935
# Abonnentens rating =  4.0
# Anbefaler film nr. 0
# Predikert rating =  4.419303130009282
# Abonnentens rating =  3.0
# Anbefaler film nr. 4
# Predikert rating =  3.366471584783607
# Abonnentens rating =  2.5
# [10, 8, 8, 10]
# ----------------
# Anbefaler film nr. 1
# Predikert rating =  4.017022296811317
# Abonnentens rating =  4.0
# Anbefaler film nr. 3
# Predikert rating =  3.872512586909608
# Abonnentens rating =  4.0
# Anbefaler film nr. 0
# Predikert rating =  3.8574482538160324
# Abonnentens rating =  5.0
# Anbefaler film nr. 4
# Predikert rating =  3.5533645009190398
# Abonnentens rating =  3.5
# [2, 2, 2, 2]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.557173895550013
# Abonnentens rating =  5.0
# Anbefaler film nr. 4
# Predikert rating =  4.066226764303528
# Abonnentens rating =  4.5
# Anbefaler film nr. 0
# Predikert rating =  4.579924242424246
# Abonnentens rating =  4.5
# Anbefaler film nr. 1
# Predikert rating =  4.084659090909091
# Abonnentens rating =  4.0
# [0, 0, 4, 4]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4

# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.021897226884044
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  4.017022296811317
# Abonnentens rating =  3.0
# Anbefaler film nr. 4
# Predikert rating =  4.066226764303528
# Abonnentens rating =  3.0
# Anbefaler film nr. 0
# Predikert rating =  4.419303130009282
# Abonnentens rating =  2.0
# [2, 2, 0, 8]
# ----------------
# Anbefaler film nr. 3
# Predikert rating =  4.912352551358515
# Abonnentens rating =  5.0
# Anbefaler film nr. 0
# Predikert rating =  4.381351888668001
# Abonnentens rating =  4.0
# Anbefaler film nr. 4
# Predikert rating =  3.983856858846919
# Abonnentens rating =  3.0
# Anbefaler film nr. 1
# Predikert rating =  2.8958491521133887
# Abonnentens rating =  5.0
# [5, 5, 5, 8]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.021897226884044
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  4.017022296811317
# Abonnentens rating =  4.0
# Anbefaler film nr. 0
# Predikert rating =  3.8574482538160324
# Abonnentens rating =  5.0
# Anbefaler film nr. 4
# Predikert rating =  3.5533645009190398
# Abonnentens rating =  3.0
# [2, 2, 2, 2]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.16910519020484
# Abonnentens rating =  4.5
# Anbefaler film nr. 3
# Predikert rating =  4.29317883103994
# Abonnentens rating =  5.0
# Anbefaler film nr. 4
# Predikert rating =  4.208544125913436
# Abonnentens rating =  3.5
# Anbefaler film nr. 1
# Predikert rating =  3.5032602585722317
# Abonnentens rating =  2.5
# [10, 0, 11, 11]
# ----------------
# Anbefaler film nr. 1
# Predikert rating =  4.017022296811317
# Abonnentens rating =  3.0
# Anbefaler film nr. 3
# Predikert rating =  3.981877919811075
# Abonnentens rating =  4.0
# Anbefaler film nr. 4
# Predikert rating =  4.066226764303528
# Abonnentens rating =  4.0
# Anbefaler film nr. 0
# Predikert rating =  4.049985247176846
# Abonnentens rating =  5.0
# [2, 10, 0, 0]
# ----------------
# Anbefaler film nr. 3
# Predikert rating =  4.422424702606935
# Abonnentens rating =  4.5
# Anbefaler film nr. 0
# Predikert rating =  4.419303130009282
# Abonnentens rating =  3.5
# Anbefaler film nr. 4
# Predikert rating =  4.066226764303528
# Abonnentens rating =  4.5
# Anbefaler film nr. 1
# Predikert rating =  3.5032602585722317
# Abonnentens rating =  1.5
# [8, 8, 0, 11]
# ----------------
# Anbefaler film nr. 3
# Predikert rating =  4.912352551358515
# Abonnentens rating =  5.0
# Anbefaler film nr. 0
# Predikert rating =  4.381351888668001
# Abonnentens rating =  3.0
# Anbefaler film nr. 4
# Predikert rating =  4.208544125913436
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  3.5032602585722317
# Abonnentens rating =  5.0
# [5, 5, 11, 11]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.942054340622931
# Abonnentens rating =  5.0
# Anbefaler film nr. 3
# Predikert rating =  4.912352551358515
# Abonnentens rating =  4.0
# Anbefaler film nr. 4
# Predikert rating =  4.066226764303528
# Abonnentens rating =  4.0
# Anbefaler film nr. 0
# Predikert rating =  4.049985247176846
# Abonnentens rating =  5.0
# [5, 5, 0, 0]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4
# Abonnentens rating =  3.0
# [9, 5, 5, 8]
# ----------------
# Anbefaler film nr. 3
# Predikert rating =  4.912352551358515
# Abonnentens rating =  5.0
# Anbefaler film nr. 0
# Predikert rating =  4.381351888668001
# Abonnentens rating =  3.0
# Anbefaler film nr. 4
# Predikert rating =  4.208544125913436
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  3.5032602585722317
# Abonnentens rating =  4.5
# [5, 5, 11, 11]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.021897226884044
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  4.017022296811317
# Abonnentens rating =  3.0
# Anbefaler film nr. 4
# Predikert rating =  3.366471584783607
# Abonnentens rating =  3.0
# Anbefaler film nr. 0
# Predikert rating =  4.419303130009282
# Abonnentens rating =  3.5
# [2, 2, 10, 8]
# ----------------
# Anbefaler film nr. 3
# Predikert rating =  4.912352551358515
# Abonnentens rating =  5.0
# Anbefaler film nr. 0
# Predikert rating =  4.381351888668001
# Abonnentens rating =  4.0
# Anbefaler film nr. 4
# Predikert rating =  3.983856858846919
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  3.389224652087476
# Abonnentens rating =  4.0
# [5, 5, 5, 5]
# ----------------
# Anbefaler film nr. 4
# Predikert rating =  4.803901515151512
# Abonnentens rating =  4.0
# Anbefaler film nr. 2
# Predikert rating =  4.557173895550013
# Abonnentens rating =  5.0
# Anbefaler film nr. 3
# Predikert rating =  4.912352551358515
# Abonnentens rating =  5.0
# Anbefaler film nr. 0
# Predikert rating =  4.957125684519845
# Abonnentens rating =  5.0
# [4, 0, 5, 9]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.16910519020484
# Abonnentens rating =  4.0
# Anbefaler film nr. 3
# Predikert rating =  4.616750983698706
# Abonnentens rating =  4.0
# Anbefaler film nr. 4
# Predikert rating =  4.208544125913436
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  3.5032602585722317
# Abonnentens rating =  4.0
# [10, 11, 11, 11]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.942054340622931
# Abonnentens rating =  5.0
# Anbefaler film nr. 3
# Predikert rating =  4.912352551358515
# Abonnentens rating =  4.0
# Anbefaler film nr. 4
# Predikert rating =  4.066226764303528
# Abonnentens rating =  5.0
# Anbefaler film nr. 0
# Predikert rating =  4.049985247176846
# Abonnentens rating =  4.0
# [5, 5, 0, 0]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.942578246738796
# Abonnentens rating =  4.5
# Anbefaler film nr. 3
# Predikert rating =  4.942567116334995
# Abonnentens rating =  4.5
# Anbefaler film nr. 4
# Predikert rating =  3.9664640933173043
# Abonnentens rating =  4.5
# Anbefaler film nr. 1
# Predikert rating =  4.084659090909091
# Abonnentens rating =  4.0
# [9, 9, 9, 4]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  3.9617886178861808
# Abonnentens rating =  5.0
# Anbefaler film nr. 4
# Predikert rating =  4.803901515151512
# Abonnentens rating =  2.0
# Anbefaler film nr. 1
# Predikert rating =  4.017022296811317
# Abonnentens rating =  1.5
# Anbefaler film nr. 0
# Predikert rating =  4.419303130009282
# Abonnentens rating =  1.0
# [1, 4, 2, 8]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4

# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.942578246738796
# Abonnentens rating =  5.0
# Anbefaler film nr. 3
# Predikert rating =  4.942567116334995
# Abonnentens rating =  4.5
# Anbefaler film nr. 4
# Predikert rating =  3.9664640933173043
# Abonnentens rating =  4.5
# Anbefaler film nr. 1
# Predikert rating =  4.084659090909091
# Abonnentens rating =  3.0
# [9, 9, 9, 4]
# ----------------
# Anbefaler film nr. 3
# Predikert rating =  4.422424702606935
# Abonnentens rating =  4.0
# Anbefaler film nr. 0
# Predikert rating =  4.419303130009282
# Abonnentens rating =  5.0
# Anbefaler film nr. 4
# Predikert rating =  3.9664640933173043
# Abonnentens rating =  4.5
# Anbefaler film nr. 1
# Predikert rating =  4.084659090909091
# Abonnentens rating =  4.5
# [8, 8, 9, 4]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.711635750421587
# Abonnentens rating =  4.5
# Anbefaler film nr. 3
# Predikert rating =  4.29317883103994
# Abonnentens rating =  4.5
# Anbefaler film nr. 1
# Predikert rating =  3.5032602585722317
# Abonnentens rating =  4.0
# Anbefaler film nr. 0
# Predikert rating =  2.807982012366507
# Abonnentens rating =  4.0
# [11, 0, 11, 11]
# ----------------
# Anbefaler film nr. 0
# Predikert rating =  4.957125684519845
# Abonnentens rating =  5.0
# Anbefaler film nr. 2
# Predikert rating =  4.942578246738796
# Abonnentens rating =  5.0
# Anbefaler film nr. 4
# Predikert rating =  3.9664640933173043
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  3.685900004452162
# Abonnentens rating =  4.0
# [9, 9, 9, 9]
# ----------------
# Anbefaler film nr. 3
# Predikert rating =  4.912352551358515
# Abonnentens rating =  3.0
# Anbefaler film nr. 4
# Predikert rating =  4.803901515151512
# Abonnentens rating =  2.0
# Anbefaler film nr. 1
# Predikert rating =  4.017022296811317
# Abonnentens rating =  3.0
# Anbefaler film nr. 0
# Predikert rating =  4.419303130009282
# Abonnentens rating =  5.0
# [5, 4, 2, 8]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.021897226884044
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  4.017022296811317
# Abonnentens rating =  3.5
# Anbefaler film nr. 0
# Predikert rating =  3.8574482538160324
# Abonnentens rating =  4.0
# Anbefaler film nr. 4
# Predikert rating =  3.5533645009190398
# Abonnentens rating =  4.5
# [2, 2, 2, 2]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.16910519020484
# Abonnentens rating =  5.0
# Anbefaler film nr. 3
# Predikert rating =  4.912352551358515
# Abonnentens rating =  4.0
# Anbefaler film nr. 4
# Predikert rating =  4.066226764303528
# Abonnentens rating =  3.5
# Anbefaler film nr. 1
# Predikert rating =  3.2707008932163846
# Abonnentens rating =  3.5
# [10, 5, 0, 0]
# ----------------
# Anbefaler film nr. 3
# Predikert rating =  4.912352551358515
# Abonnentens rating =  5.0
# Anbefaler film nr. 0
# Predikert rating =  4.381351888668001
# Abonnentens rating =  4.0
# Anbefaler film nr. 4
# Predikert rating =  3.983856858846919
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  3.389224652087476
# Abonnentens rating =  4.0
# [5, 5, 5, 5]
# ----------------
# Anbefaler film nr. 1
# Predikert rating =  4.017022296811317
# Abonnentens rating =  3.0
# Anbefaler film nr. 3
# Predikert rating =  3.981877919811075
# Abonnentens rating =  3.0
# Anbefaler film nr. 4
# Predikert rating =  3.366471584783607
# Abonnentens rating =  4.0
# Anbefaler film nr. 0
# Predikert rating =  3.1147646183069053
# Abonnentens rating =  2.0
# [2, 10, 10, 10]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4

# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.557173895550013
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  4.017022296811317
# Abonnentens rating =  3.0
# Anbefaler film nr. 3
# Predikert rating =  4.29317883103994
# Abonnentens rating =  4.0
# Anbefaler film nr. 0
# Predikert rating =  4.049985247176846
# Abonnentens rating =  4.0
# [0, 2, 0, 0]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.942054340622931
# Abonnentens rating =  5.0
# Anbefaler film nr. 3
# Predikert rating =  4.912352551358515
# Abonnentens rating =  4.0
# Anbefaler film nr. 4
# Predikert rating =  4.066226764303528
# Abonnentens rating =  3.0
# Anbefaler film nr. 0
# Predikert rating =  4.419303130009282
# Abonnentens rating =  3.0
# [5, 5, 0, 8]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.021897226884044
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  4.017022296811317
# Abonnentens rating =  3.0
# Anbefaler film nr. 4
# Predikert rating =  4.066226764303528
# Abonnentens rating =  4.0
# Anbefaler film nr. 0
# Predikert rating =  4.049985247176846
# Abonnentens rating =  1.0
# [2, 2, 0, 0]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.750530303030305
# Abonnentens rating =  5.0
# Anbefaler film nr. 3
# Predikert rating =  4.912352551358515
# Abonnentens rating =  4.0
# Anbefaler film nr. 0
# Predikert rating =  4.049985247176846
# Abonnentens rating =  5.0
# Anbefaler film nr. 1
# Predikert rating =  4.084659090909091
# Abonnentens rating =  4.0
# [4, 5, 0, 4]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.021897226884044
# Abonnentens rating =  5.0
# Anbefaler film nr. 4
# Predikert rating =  4.066226764303528
# Abonnentens rating =  5.0
# Anbefaler film nr. 0
# Predikert rating =  4.049985247176846
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  4.084659090909091
# Abonnentens rating =  3.0
# [2, 0, 0, 4]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.16910519020484
# Abonnentens rating =  5.0
# Anbefaler film nr. 3
# Predikert rating =  4.912352551358515
# Abonnentens rating =  4.5
# Anbefaler film nr. 4
# Predikert rating =  4.066226764303528
# Abonnentens rating =  4.0
# Anbefaler film nr. 0
# Predikert rating =  4.049985247176846
# Abonnentens rating =  4.0
# [10, 5, 0, 0]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.557173895550013
# Abonnentens rating =  5.0
# Anbefaler film nr. 3
# Predikert rating =  4.912352551358515
# Abonnentens rating =  5.0
# Anbefaler film nr. 0
# Predikert rating =  4.381351888668001
# Abonnentens rating =  3.5
# Anbefaler film nr. 4
# Predikert rating =  3.983856858846919
# Abonnentens rating =  3.5
# [0, 5, 5, 5]
# ----------------
# Anbefaler film nr. 3
# Predikert rating =  4.912352551358515
# Abonnentens rating =  5.0
# Anbefaler film nr. 0
# Predikert rating =  4.381351888668001
# Abonnentens rating =  4.0
# Anbefaler film nr. 4
# Predikert rating =  3.983856858846919
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  3.389224652087476
# Abonnentens rating =  4.0
# [5, 5, 5, 5]
# ----------------
# Anbefaler film nr. 0
# Predikert rating =  4.957125684519845
# Abonnentens rating =  3.0
# Anbefaler film nr. 2
# Predikert rating =  4.16910519020484
# Abonnentens rating =  5.0
# Anbefaler film nr. 4
# Predikert rating =  4.208544125913436
# Abonnentens rating =  2.0
# Anbefaler film nr. 1
# Predikert rating =  3.8040955631399314
# Abonnentens rating =  2.0
# [9, 10, 11, 6]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4

# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.557173895550013
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  4.017022296811317
# Abonnentens rating =  2.0
# Anbefaler film nr. 3
# Predikert rating =  3.981877919811075
# Abonnentens rating =  4.0
# Anbefaler film nr. 0
# Predikert rating =  4.049985247176846
# Abonnentens rating =  4.0
# [0, 2, 10, 0]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.16910519020484
# Abonnentens rating =  5.0
# Anbefaler film nr. 3
# Predikert rating =  4.616750983698706
# Abonnentens rating =  4.5
# Anbefaler film nr. 4
# Predikert rating =  4.208544125913436
# Abonnentens rating =  3.5
# Anbefaler film nr. 1
# Predikert rating =  3.5032602585722317
# Abonnentens rating =  3.0
# [10, 11, 11, 11]
# ----------------
# Anbefaler film nr. 0
# Predikert rating =  4.957125684519845
# Abonnentens rating =  4.0
# Anbefaler film nr. 2
# Predikert rating =  4.942054340622931
# Abonnentens rating =  5.0
# Anbefaler film nr. 4
# Predikert rating =  3.983856858846919
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  3.389224652087476
# Abonnentens rating =  2.0
# [9, 5, 5, 5]
# ----------------
# Anbefaler film nr. 3
# Predikert rating =  4.912352551358515
# Abonnentens rating =  5.0
# Anbefaler film nr. 0
# Predikert rating =  4.381351888668001
# Abonnentens rating =  4.5
# Anbefaler film nr. 4
# Predikert rating =  3.9664640933173043
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  3.685900004452162
# Abonnentens rating =  2.0
# [5, 5, 9, 9]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.942054340622931
# Abonnentens rating =  2.5
# Anbefaler film nr. 1
# Predikert rating =  3.4466310873915944
# Abonnentens rating =  4.0
# Anbefaler film nr. 0
# Predikert rating =  3.619430785277905
# Abonnentens rating =  5.0
# Anbefaler film nr. 3
# Predikert rating =  3.2643048725972266
# Abonnentens rating =  2.0
# [5, 7, 3, 3]
# ----------------
# Anbefaler film nr. 3
# Predikert rating =  4.422424702606935
# Abonnentens rating =  4.5
# Anbefaler film nr. 0
# Predikert rating =  4.419303130009282
# Abonnentens rating =  4.5
# Anbefaler film nr. 4
# Predikert rating =  4.803901515151512
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  4.084659090909091
# Abonnentens rating =  3.5
# [8, 8, 4, 4]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.16910519020484
# Abonnentens rating =  5.0
# Anbefaler film nr. 3
# Predikert rating =  4.616750983698706
# Abonnentens rating =  5.0
# Anbefaler film nr. 4
# Predikert rating =  4.208544125913436
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  3.5032602585722317
# Abonnentens rating =  3.5
# [10, 11, 11, 11]
# ----------------
# Anbefaler film nr. 3
# Predikert rating =  4.912352551358515
# Abonnentens rating =  5.0
# Anbefaler film nr. 0
# Predikert rating =  4.381351888668001
# Abonnentens rating =  5.0
# Anbefaler film nr. 4
# Predikert rating =  3.9664640933173043
# Abonnentens rating =  3.0
# Anbefaler film nr. 1
# Predikert rating =  3.685900004452162
# Abonnentens rating =  3.0
# [5, 5, 9, 9]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.557173895550013
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  4.017022296811317
# Abonnentens rating =  4.5
# Anbefaler film nr. 3
# Predikert rating =  3.872512586909608
# Abonnentens rating =  4.0
# Anbefaler film nr. 0
# Predikert rating =  3.8574482538160324
# Abonnentens rating =  5.0
# [0, 2, 2, 2]
# ----------------
# Anbefaler film nr. 1
# Predikert rating =  4.017022296811317
# Abonnentens rating =  3.5
# Anbefaler film nr. 3
# Predikert rating =  3.872512586909608
# Abonnentens rating =  4.0
# Anbefaler film nr. 0
# Predikert rating =  3.8574482538160324
# Abonnentens rating =  3.0
# Anbefaler film nr. 4
# Predikert rating =  3.5533645009190398
# Abonnentens rating =  2.0
# [2, 2, 2, 2]
# ----------------
# Anbefaler film nr. 4
# Predikert rating =  4.803901515151512
# Abonnentens rating =  3.5
# Anbefaler film nr. 2
# Predikert rating =  4.942054340622931
# Abonnentens rating =  2.5
# Anbefaler film nr. 0
# Predikert rating =  3.619430785277905
# Abonnentens rating =  3.0
# Anbefaler film nr. 3
# Predikert rating =  3.2643048725972266
# Abonnentens rating =  2.0
# [4, 5, 3, 3]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.750530303030305
# Abonnentens rating =  5.0
# Anbefaler film nr. 3
# Predikert rating =  4.912352551358515
# Abonnentens rating =  5.0
# Anbefaler film nr. 0
# Predikert rating =  4.579924242424246
# Abonnentens rating =  5.0
# Anbefaler film nr. 1
# Predikert rating =  4.084659090909091
# Abonnentens rating =  4.0
# [4, 5, 4, 4]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.021897226884044
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  4.017022296811317
# Abonnentens rating =  4.0
# Anbefaler film nr. 0
# Predikert rating =  3.8574482538160324
# Abonnentens rating =  3.5
# Anbefaler film nr. 4
# Predikert rating =  3.5533645009190398
# Abonnentens rating =  4.0
# [2, 2, 2, 2]
# ----------------
# Anbefaler film nr. 1
# Predikert rating =  4.017022296811317
# Abonnentens rating =  3.0
# Anbefaler film nr. 3
# Predikert rating =  3.981877919811075
# Abonnentens rating =  4.0
# Anbefaler film nr. 4
# Predikert rating =  4.066226764303528
# Abonnentens rating =  3.0
# Anbefaler film nr. 0
# Predikert rating =  4.419303130009282
# Abonnentens rating =  4.0
# [2, 10, 0, 8]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.942054340622931
# Abonnentens rating =  4.5
# Anbefaler film nr. 3
# Predikert rating =  4.942567116334995
# Abonnentens rating =  4.5
# Anbefaler film nr. 4
# Predikert rating =  4.803901515151512
# Abonnentens rating =  4.5
# Anbefaler film nr. 1
# Predikert rating =  4.084659090909091
# Abonnentens rating =  4.0
# [5, 9, 4, 4]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.942578246738796
# Abonnentens rating =  5.0
# Anbefaler film nr. 3
# Predikert rating =  4.942567116334995
# Abonnentens rating =  5.0
# Anbefaler film nr. 4
# Predikert rating =  3.9664640933173043
# Abonnentens rating =  1.0
# Anbefaler film nr. 1
# Predikert rating =  2.8958491521133887
# Abonnentens rating =  1.0
# [9, 9, 9, 8]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4

# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.942578246738796
# Abonnentens rating =  4.0
# Anbefaler film nr. 3
# Predikert rating =  4.942567116334995
# Abonnentens rating =  4.0
# Anbefaler film nr. 4
# Predikert rating =  4.066226764303528
# Abonnentens rating =  3.5
# Anbefaler film nr. 1
# Predikert rating =  4.017022296811317
# Abonnentens rating =  4.0
# [9, 9, 0, 2]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.557173895550013
# Abonnentens rating =  4.5
# Anbefaler film nr. 3
# Predikert rating =  4.29317883103994
# Abonnentens rating =  4.0
# Anbefaler film nr. 0
# Predikert rating =  4.049985247176846
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  4.017022296811317
# Abonnentens rating =  3.5
# [0, 0, 0, 2]
# ----------------
# Anbefaler film nr. 1
# Predikert rating =  4.017022296811317
# Abonnentens rating =  4.0
# Anbefaler film nr. 3
# Predikert rating =  3.872512586909608
# Abonnentens rating =  4.0
# Anbefaler film nr. 0
# Predikert rating =  3.8574482538160324
# Abonnentens rating =  4.0
# Anbefaler film nr. 4
# Predikert rating =  3.5533645009190398
# Abonnentens rating =  5.0
# [2, 2, 2, 2]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.557173895550013
# Abonnentens rating =  5.0
# Anbefaler film nr. 3
# Predikert rating =  4.29317883103994
# Abonnentens rating =  5.0
# Anbefaler film nr. 0
# Predikert rating =  4.381351888668001
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  3.389224652087476
# Abonnentens rating =  3.5
# [0, 0, 5, 5]
# ----------------
# Anbefaler film nr. 3
# Predikert rating =  4.912352551358515
# Abonnentens rating =  3.0
# Anbefaler film nr. 4
# Predikert rating =  4.803901515151512
# Abonnentens rating =  5.0
# Anbefaler film nr. 0
# Predikert rating =  4.579924242424246
# Abonnentens rating =  5.0
# Anbefaler film nr. 1
# Predikert rating =  4.084659090909091
# Abonnentens rating =  4.0
# [5, 4, 4, 4]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.5787564329705575
# Abonnentens rating =  5.0
# Anbefaler film nr. 3
# Predikert rating =  4.422424702606935
# Abonnentens rating =  4.0
# Anbefaler film nr. 0
# Predikert rating =  4.419303130009282
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  2.8958491521133887
# Abonnentens rating =  4.0
# [8, 8, 8, 8]
# ----------------
# Anbefaler film nr. 3
# Predikert rating =  4.816951080773605
# Abonnentens rating =  5.0
# Anbefaler film nr. 2
# Predikert rating =  4.810921501706485
# Abonnentens rating =  5.0
# Anbefaler film nr. 4
# Predikert rating =  4.208544125913436
# Abonnentens rating =  2.0
# Anbefaler film nr. 1
# Predikert rating =  3.8040955631399314
# Abonnentens rating =  3.0
# [6, 6, 11, 6]
# ----------------
# Anbefaler film nr. 2
# Predikert rating =  4.5787564329705575
# Abonnentens rating =  5.0
# Anbefaler film nr. 3
# Predikert rating =  4.422424702606935
# Abonnentens rating =  5.0
# Anbefaler film nr. 0
# Predikert rating =  4.419303130009282
# Abonnentens rating =  4.0
# Anbefaler film nr. 1
# Predikert rating =  2.8958491521133887
# Abonnentens rating =  2.0
# [8, 8, 8, 8]
# ----------------
