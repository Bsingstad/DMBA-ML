# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import  train_test_split 
import math
from tensorflow.keras.utils import to_categorical
import os
import cv2

# %%
cat_path = "datasett-hundogkatt/training_set/training_set/cats/"
dog_path = "datasett-hundogkatt/training_set/training_set/dogs/"

# %%
cat_img = []
for i in os.listdir(cat_path):
    if i.endswith(".jpg"):
        temp_img = cv2.imread(os.path.join(cat_path, i), cv2.IMREAD_COLOR)[:,:,::-1]
        temp_img = cv2.resize(temp_img, (64,64), interpolation= cv2.INTER_LINEAR )
        cat_img.append(temp_img)

# %%
cat_img = np.asarray(cat_img)

# %%
y_cat = np.zeros(cat_img.shape[0])

# %%
dog_img = []
for i in os.listdir(dog_path):
    if i.endswith(".jpg"):
        temp_img = cv2.imread(os.path.join(dog_path, i), cv2.IMREAD_COLOR)[:,:,::-1]
        temp_img = cv2.resize(temp_img, (64,64), interpolation= cv2.INTER_LINEAR )
        dog_img.append(temp_img)

# %%
dog_img = np.asarray(dog_img)

# %%
y_dog = np.ones(dog_img.shape[0])

# %%
plt.figure(figsize=(20,8))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(cat_img[i])
    plt.xticks([])
    plt.yticks([])
plt.savefig("cat_images.png",dpi=100)

# %%
plt.figure(figsize=(20,8))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(dog_img[i])
    plt.xticks([])
    plt.yticks([])
plt.savefig("dog_images.png",dpi=100)

# %%
X = np.vstack([cat_img,dog_img])

# %%
y = np.hstack([y_cat,y_dog])

# %%
X_train, X_val, y_train, y_val = train_test_split(X,y, test_size=0.2)

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([0., 1.]), array([3194, 3210], dtype=int64))

# %%
np.unique(y_val, return_counts=True)
# Out:
# (array([0., 1.]), array([806, 795], dtype=int64))

# %%
y_train = np.expand_dims(y_train ,-1)

# %%
X_train.shape
# Out:
# (6404, 64, 64, 3)

# %%
base_model = tf.keras.applications.EfficientNetV2B0(
    include_top=False,
    weights="imagenet",
    classes=1,
    classifier_activation="softmax",
    input_shape=(64, 64, 3)
)

# %%
# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# %%
x = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(128, activation="relu")(x)
pred = tf.keras.layers.Dense(1, activation="sigmoid")(x)
model = tf.keras.Model(inputs = base_model.input, outputs = pred)

# %%
model.compile(loss="binary_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001), 
                metrics = [tf.keras.metrics.BinaryAccuracy(),tf.keras.metrics.AUC(curve='ROC')])

# %%
history = model.fit(x=X_train,y=y_train, epochs=25, batch_size=64, validation_data=(X_val,y_val), shuffle=True)
# Out:
# Epoch 1/25
# 101/101 [==============================] - 286s 1s/step - loss: 0.6832 - binary_accuracy: 0.5562 - auc: 0.5834 - val_loss: 0.6487 - val_binary_accuracy: 0.6421 - val_auc: 0.6886
# Epoch 2/25
# 101/101 [==============================] - 72s 717ms/step - loss: 0.6220 - binary_accuracy: 0.6847 - auc: 0.7495 - val_loss: 0.5936 - val_binary_accuracy: 0.7245 - val_auc: 0.8060
# Epoch 3/25
# 101/101 [==============================] - 73s 727ms/step - loss: 0.5731 - binary_accuracy: 0.7516 - auc: 0.8315 - val_loss: 0.5492 - val_binary_accuracy: 0.7745 - val_auc: 0.8596
# Epoch 4/25
# 101/101 [==============================] - 448s 4s/step - loss: 0.5318 - binary_accuracy: 0.7951 - auc: 0.8742 - val_loss: 0.5128 - val_binary_accuracy: 0.8001 - val_auc: 0.8868
# Epoch 5/25
# 101/101 [==============================] - 55s 545ms/step - loss: 0.4975 - binary_accuracy: 0.8156 - auc: 0.8953 - val_loss: 0.4820 - val_binary_accuracy: 0.8107 - val_auc: 0.9019
# Epoch 6/25
# 101/101 [==============================] - 54s 535ms/step - loss: 0.4717 - binary_accuracy: 0.8218 - auc: 0.9049 - val_loss: 0.4573 - val_binary_accuracy: 0.8239 - val_auc: 0.9115
# Epoch 7/25
# 101/101 [==============================] - 56s 555ms/step - loss: 0.4490 - binary_accuracy: 0.8314 - auc: 0.9111 - val_loss: 0.4360 - val_binary_accuracy: 0.8339 - val_auc: 0.9178
# Epoch 8/25
# 101/101 [==============================] - 58s 571ms/step - loss: 0.4295 - binary_accuracy: 0.8403 - auc: 0.9185 - val_loss: 0.4182 - val_binary_accuracy: 0.8401 - val_auc: 0.9225
# Epoch 9/25
# 101/101 [==============================] - 55s 549ms/step - loss: 0.4140 - binary_accuracy: 0.8471 - auc: 0.9215 - val_loss: 0.4025 - val_binary_accuracy: 0.8457 - val_auc: 0.9259
# Epoch 10/25
# 101/101 [==============================] - 42s 420ms/step - loss: 0.3988 - binary_accuracy: 0.8487 - auc: 0.9262 - val_loss: 0.3894 - val_binary_accuracy: 0.8463 - val_auc: 0.9288
# Epoch 11/25
# 101/101 [==============================] - 36s 359ms/step - loss: 0.3836 - binary_accuracy: 0.8532 - auc: 0.9312 - val_loss: 0.3781 - val_binary_accuracy: 0.8482 - val_auc: 0.9310
# Epoch 12/25
# 101/101 [==============================] - 35s 351ms/step - loss: 0.3736 - binary_accuracy: 0.8577 - auc: 0.9326 - val_loss: 0.3685 - val_binary_accuracy: 0.8495 - val_auc: 0.9328
# Epoch 13/25
# 101/101 [==============================] - 33s 327ms/step - loss: 0.3664 - binary_accuracy: 0.8546 - auc: 0.9332 - val_loss: 0.3601 - val_binary_accuracy: 0.8545 - val_auc: 0.9343
# Epoch 14/25
# 101/101 [==============================] - 25s 248ms/step - loss: 0.3552 - binary_accuracy: 0.8609 - auc: 0.9368 - val_loss: 0.3527 - val_binary_accuracy: 0.8551 - val_auc: 0.9357
# Epoch 15/25
# 101/101 [==============================] - 25s 246ms/step - loss: 0.3447 - binary_accuracy: 0.8648 - auc: 0.9391 - val_loss: 0.3466 - val_binary_accuracy: 0.8588 - val_auc: 0.9368
# Epoch 16/25
# 101/101 [==============================] - 27s 265ms/step - loss: 0.3441 - binary_accuracy: 0.8585 - auc: 0.9370 - val_loss: 0.3412 - val_binary_accuracy: 0.8595 - val_auc: 0.9379
# Epoch 17/25
# 101/101 [==============================] - 28s 281ms/step - loss: 0.3350 - binary_accuracy: 0.8682 - auc: 0.9413 - val_loss: 0.3362 - val_binary_accuracy: 0.8620 - val_auc: 0.9389
# Epoch 18/25
# 101/101 [==============================] - 26s 255ms/step - loss: 0.3320 - binary_accuracy: 0.8701 - auc: 0.9412 - val_loss: 0.3321 - val_binary_accuracy: 0.8651 - val_auc: 0.9396
# Epoch 19/25
# 101/101 [==============================] - 24s 240ms/step - loss: 0.3238 - binary_accuracy: 0.8673 - auc: 0.9441 - val_loss: 0.3281 - val_binary_accuracy: 0.8657 - val_auc: 0.9403
# Epoch 20/25
# 101/101 [==============================] - 24s 241ms/step - loss: 0.3237 - binary_accuracy: 0.8699 - auc: 0.9426 - val_loss: 0.3248 - val_binary_accuracy: 0.8645 - val_auc: 0.9409
# Epoch 21/25
# 101/101 [==============================] - 24s 242ms/step - loss: 0.3158 - binary_accuracy: 0.8759 - auc: 0.9456 - val_loss: 0.3217 - val_binary_accuracy: 0.8645 - val_auc: 0.9415
# Epoch 22/25
# 101/101 [==============================] - 23s 233ms/step - loss: 0.3153 - binary_accuracy: 0.8705 - auc: 0.9445 - val_loss: 0.3190 - val_binary_accuracy: 0.8676 - val_auc: 0.9420
# Epoch 23/25
# 101/101 [==============================] - 24s 235ms/step - loss: 0.3079 - binary_accuracy: 0.8716 - auc: 0.9472 - val_loss: 0.3167 - val_binary_accuracy: 0.8676 - val_auc: 0.9425
# Epoch 24/25
# 101/101 [==============================] - 24s 238ms/step - loss: 0.3080 - binary_accuracy: 0.8702 - auc: 0.9467 - val_loss: 0.3144 - val_binary_accuracy: 0.8701 - val_auc: 0.9429
# Epoch 25/25
# 101/101 [==============================] - 22s 220ms/step - loss: 0.3002 - binary_accuracy: 0.8788 - auc: 0.9499 - val_loss: 0.3122 - val_binary_accuracy: 0.8695 - val_auc: 0.9433

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history["loss"], label="loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.legend()

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history[list(history.history.keys())[2]], label="AUROC")
plt.plot(history.history[list(history.history.keys())[5]], label="val_AUROC")
plt.legend()
